# %%
import pandas as pd 
import numpy as np 
import plotly.graph_objects as go

# %%
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv(r"C:\works\learnings\logisitic_supply_chain\archive\DataCoSupplyChainDataset.csv", sep = ",", encoding="latin1")
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.isna().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df.describe(include='all').T
# Out:
#                                   count unique  \
# Type                             180519      4
# Days for shipping (real)       180519.0    NaN
# Days for shipment (scheduled)  180519.0    NaN
# Benefit per order              180519.0    NaN
# Sales per customer             180519.0    NaN
# Delivery Status                  180519      4
# Late_delivery_risk             180519.0    NaN
# Category Id                    180519.0    NaN
# Category Name                    180519     50
# Customer City                    180519    563
# Customer Country                 180519      2
# Customer Email                   180519      1
# Customer Fname                   180519    782
# Customer Id                    180519.0    NaN
# Customer Lname                   180511   1109
# Customer Password                180519      1
# Customer Segment                 180519      3
# Customer State                   180519     46
# Customer Street                  180519   7458
# ...

# %%
columns = df.columns
id_named_columns = []
for  col in columns:
    if "Id" in col :
        id_named_columns.append(col)
id_named_columns
# Out:
# ['Category Id',
#  'Customer Id',
#  'Department Id',
#  'Order Customer Id',
#  'Order Id',
#  'Order Item Cardprod Id',
#  'Order Item Id',
#  'Product Card Id',
#  'Product Category Id']

# %%
id_named_columns_df = df[id_named_columns]
id_named_columns_df.head()
# Out:
#    Category Id  Customer Id  Department Id  Order Customer Id  Order Id  \
# 0           73        20755              2              20755     77202
# 1           73        19492              2              19492     75939
# 2           73        19491              2              19491     75938
# 3           73        19490              2              19490     75937
# 4           73        19489              2              19489     75936
#
#    Order Item Cardprod Id  Order Item Id  Product Card Id  Product Category Id
# 0                    1360         180517             1360                   73
# 1                    1360         179254             1360                   73
# 2                    1360         179253             1360                   73
# 3                    1360         179252             1360                   73
# 4                    1360         179251             1360                   73

# %%
sum((id_named_columns_df["Customer Id"].values) != (id_named_columns_df["Order Customer Id"].values))
# Out:
# 0

# %%
pairs = [
    ("Category Id", "Product Category Id"),
    ("Product Card Id", "Order Item Cardprod Id"),
    ("Benefit per order", "Order Profit Per Order"),
    ("Sales per customer", "Order Item Total"),
    ("Product Price", "Order Item Product Price"),
]
drop = []
for c1, c2 in pairs:
    print(f"{c1} == {c2} :", (df[c1] == df[c2]).all())
    drop.append(c2)
# Out:
# Category Id == Product Category Id : True
# Product Card Id == Order Item Cardprod Id : True
# Benefit per order == Order Profit Per Order : True
# Sales per customer == Order Item Total : True
# Product Price == Order Item Product Price : True

# %%
df["Order Id"].nunique(), len(df)
# Out:
# (65752, 180519)

# %%
df = df.drop(columns=["Product Status"])
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
df.groupby("Order Id")["Order Item Id"].count().reset_index()
# Out:
#        Order Id  Order Item Id
# 0             1              1
# 1             2              3
# 2             4              4
# 3             5              5
# 4             7              3
# ...         ...            ...
# 65747     77200              1
# 65748     77201              1
# 65749     77202              1
# 65750     77203              1
# 65751     77204              1
#
# [65752 rows x 2 columns]
